# %% [markdown]
# <a href="https://colab.research.google.com/github/subashnamaskey/2462341_SubashnaMaskey/blob/main/2462341_SubashnaMaskey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1. Classify Study Time:
#
# 1.Create empty lists for study time classifications:
#
# (a) Low: less than 3 hours.
#
# (b) Moderate: between 3 and 5 hours.
#
# (c) High: more than 5 hours.
#
# 2.Iterate over the time_data list and add each study hour to the appropriate category.
#
# 3.Print the lists to verify the classifications.

# %%
#Task 1
# Given dataset
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

#Creating empty class lists for study time
low = []
moderate = []
high = []

#initiating the iteration for study time
for study, entertainment, sleep in time_data:
    if study < 3:
        low.append(study)
    elif 3<= study <= 5:
        moderate.append(study)
    else:
        high.append(study)

#displaying the results
#Task 7.1
print("Low study-time: ", low)
print("Moderate study time: ",moderate)
print("High study time: ",high)
# Out:
# Low study-time:  [2.5, 1.5, 2.0, 2.5]
# Moderate study time:  [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study time:  [5.5, 6.0]

# %% [markdown]
# Task 2. Based on Data – Answer all the Questions:
#
# 1.How many days had low study time?
#
# (a) Hint: Count the number of items in the low study list and print the result.
#
# 2.How many days had moderate study time?
#
# 3.How many days had high study time?
#
# Task 3. Convert Study Hours to Minutes:
# Convert each study hour value into minutes and store it in a new list called study_minutes.
#
# Formula: Minutes = Hours × 60
#
# 1.Iterate over the time_data list and apply the formula to the study hours.
#
# 2.Store the results in the new list.
#
# 3.Print the converted values.

# %%
#Task 7.2
print("Low study days: ",len(low))
print("Moderate study days: ",len(moderate))
print("High study days: ",len(high))

#creating new list for storing the study data in minutes
study_minutes = []

#iterating over the time_data
for study, entertainment,sleep in time_data:
    study = study*60
    study_minutes.append(study)

#displaying data for Task 7.3
print("The study time in minutes: ",study_minutes)
# Out:
# Low study days:  4
# Moderate study days:  9
# High study days:  2
# The study time in minutes:  [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# Task 4. Analyze Average Time Use:
# Scenario: Each record contains daily hours of study, entertainment, and sleep.
#
# 1.Create empty lists for study_hours, entertainment_hours, and sleep_hours.
#
# 2.Iterate over time_data and extract values into each list.
#
# 3.Calculate and print:
#
# (a) Average hours spent studying.
#
# (b) Average hours spent on entertainment.
#
# (c) Average hours spent sleeping.

# %%
#creating new lists for study, entertainment and sleep
study_hours = []
entertainment_hours = []
sleep_hours = []

#initiating for loop for them
for study, entertainment, sleep in time_data:
    study_hours.append(study)
    entertainment_hours.append(entertainment)
    sleep_hours.append(sleep)

#calculating average hours for each
avg_study = sum(study_hours)/len(study_hours)
avg_entertainment = sum(entertainment_hours)/len(entertainment_hours)
avg_sleep = sum(sleep_hours)/len(sleep_hours)

#displaying data for Task 7.4
print("Average hours spent on studying: ",avg_study)
print("Average hours spent on entertainment: ",avg_entertainment)
print("Average hours spent on sleep: ",avg_sleep)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6374423.py in <cell line: 0>()
#       5
#       6 #initiating for loop for them
# ----> 7 for study, entertainment, sleep in time_data:
#       8     study_hours.append(study)
#       9     entertainment_hours.append(entertainment)
#
# NameError: name 'time_data' is not defined

# %% [markdown]
# Task 5. Visualization - Study vs Sleep Pattern:
#
# 1.Import matplotlib.pyplot as plt.
#
# 2.Plot a scatter plot with:
#
# • x-axis: Study hours
#
# • y-axis: Sleep hours
#
# 3.Add labels, title, and color.

# %%
#importing library function
import matplotlib.pyplot as plt
# Extract study and sleep values
study_hours = [record[0] for record in time_data]
sleep_hours = [record[2] for record in time_data]

# Create scatter plot
plt.scatter(study_hours, sleep_hours, color='blue')

# Add labels and title
plt.xlabel('Study Hours')
plt.ylabel('Sleep Hours')
plt.title('Study vs Sleep Pattern')

# Display the plot as for Task 5
plt.show()
# Out:
# Low study-time:  [2.5, 1.5, 2.0, 2.5]
# Moderate study time:  [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study time:  [5.5, 6.0]
# Low study days:  4
# Moderate study days:  9
# High study days:  2
# The study time in minutes:  [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]
# Average hours spent on studying:  3.7
# Average hours spent on entertainment:  2.5
# Average hours spent on sleep:  7.166666666666667

# %% [markdown]
# Task 1 - Sum of Nested Lists:
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
#
# You want to find the total sum of all the numbers in this structure.
# Task:
# • Write a recursive function sum_nested_list(nested_list) that:
#
# 1.Takes a nested list (a list that can contain numbers or other lists of numbers) as input.
#
# 2.Sums all numbers at every depth level of the list, regardless of how deeply nested the numbers are.
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.

# %%
#Task 8.1.1
#Declaring recursive function for nested list
def sum_nested_list(nested_list):
    """
    Calculate the sum of all numbers in a nested list.
    This function takes a list that may contain integers and other nested lists.
    It recursively traverses the list and sums all the integers, no matter how deeply nested they are.
    Args:
         nested_list (list): A list that may contain integers or other lists of integers.
    Returns:
         int: The total sum of all integers in the nested list, including those in sublists.
    Example:
         >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
         36
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):
            total += sum_nested_list(element)
        else:
            total += element
    return total
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]

#Displaying Task 8.1.1
print(sum_nested_list(nested_list))

# %% [markdown]
# Task 2 - Generate All Permutations of a String:
#
# Scenario: Given a string, generate all possible permutations of its characters. This is useful for understanding backtracking and recursive depth-first search.
#
# Task:
#
# • Write a recursive function generate_permutations(s) that:
#
# – Takes a string s as input and returns a list of all unique permutations.
#
# • Test with strings like ”abc” and ”aab”.
#
# print(generate_permutations("abc"))
#
# Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
    """
    Generate all unique permutations of a string using recursion.
    This function takes a string as input and returns a list of all unique permutations
    of its characters. It handles repeated characters by ensuring duplicates are not included.

    Args:
        s (str): The input string to generate permutations for.

    Returns:
        list: A list of strings, each being a unique permutation of the input string.

    Example:
        >>> generate_permutations("aab")
        ['aab', 'aba', 'baa']
    """
    if len(s) <= 1:
        return [s]

    permutations = []
    unique_chars = set()  # Prevent duplicate permutations for repeated characters

    for i in range(len(s)):
        char = s[i]

        if char in unique_chars:
            continue
        unique_chars.add(char)

        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.append(char + perm)

    return permutations

#Displaying Task 8.2
print(generate_permutations("abc"))

print(generate_permutations("aab"))

# %% [markdown]
# Task 3 - Directory Size Calculation:
#
# Directory Size Calculation Scenario: Imagine a file system where directories can contain files (with sizes in KB) and other directories. You want to calculate the total size of a directory, including all nested files and subdirectories.

# %%
def calculate_directory_size(directory):
    """
    Recursively calculate the total size of a directory.

    Args:
        directory (dict): Keys are file or folder names; values are integers (file sizes) or dictionaries (subdirectories).

    Returns:
        int: Total size of all files in the directory, including nested subdirectories.

    Example for reference:
        >>> small_folder = {
        ...     "file1.txt": 20,
        ...     "file2.txt": 30,
        ...     "subfolder": {
        ...         "fileC.txt": 20
        ...     }
        ... }
        >>> calculate_directory_size(small_folder)
        70
    """
    total_size = 0

    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value

    return total_size
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

print(calculate_directory_size(directory_structure) ,"KB")
# Out:
# 36
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']
# 1400 KB

# %% [markdown]
# Task 1 - Coin Change Problem:
#
# Scenario: Given a set of coin denominations and a target amount, find the minimum number of coins needed to make the amount. If it’s not possible, return - 1.
#
# Task:
#
# 1. Write a function min_coins(coins, amount) that:
#
# • Uses DP to calculate the minimum number of coins needed to make up the
# amount.
#
# 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).

# %%
#Task 8.2.1
#declaring the funtion for minimum number of coins to make up a given amount
def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic programming.
    This function solves the coin change problem by determining the fewest number of coins from a given set of coin denominations
    that sum up to a target amount. The solution uses dynamic programming(tabulation) to iteratively build up the minimum number of coins
    required for each amount.
    Parameters:
    coins (list of int): A list of coin denominations available for making change. Each coin denomination is a positive integer.
    amount (int): The target amount for which we need to find the minimum number of coins. It must be a non-negative integer.
    Returns:
         int: The minimum number of coins required to make the given amount.
         If it is not possible to make the amount with the given coins, returns -1.
    Example:
         >>> min_coins([1, 2, 5], 11)
         3
         >>> min_coins([2], 3)
         -1
    """
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0   # 0 coins to make amount 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1
#displaying the output for Task 8.2.1
print(min_coins([1, 2, 5], 11))
# Out:
# 3

# %% [markdown]
# Task 2 - Longest Common Subsequence (LCS):
# Scenario: Given two strings, find the length of their longest common subsequence (LCS). This is useful in text comparison.
#
# Task:
#
# 1. Write a function longest_common_subsequence(s1, s2) that:
#
# • Uses DP to find the length of the LCS of two strings s1 and s2.
#
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
#declaring the function for finding the longest common subsequence
def longest_common_subsequence(s1, s2):
    """
    Calculate the length of the longest common subsequence (LCS) between two strings.
    This function uses a bottom-up dynamic programming approach to find the LCS efficiently.

    Args:
        s1 (str): The first string.
        s2 (str): The second string.

    Returns:
        int: The length of the longest common subsequence between s1 and s2.

    Example:
        >>> longest_common_subsequence("abcde", "ace")
        3
        >>> longest_common_subsequence("abc", "abc")
        3
        >>> longest_common_subsequence("abc", "def")
        0
    """

    m, n = len(s1), len(s2)

    # DP table of size (m+1) x (n+1)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    # Fill table
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:  # match
                dp[i][j] = 1 + dp[i - 1][j - 1]
            else:  # no match
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]
#displying output for Task 8.2.2
print(longest_common_subsequence("abcde", "ace"))

# %% [markdown]
# Task 3 - 0/1 Knapsack Problem:
#
# Scenario: You have a list of items, each with a weight and a value. Given a weight capacity, maximize the total value of items you can carry without exceeding the weight capacity.
#
# Task:
#
# 1. Write a function knapsack(weights, values, capacity) that:
# • Uses DP to determine the maximum value that can be achieved within the given weight capacity.
#
# 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re-
# sult should be 9.

# %%
#declaring function for knapsack
def knapsack(weights, values, capacity):
    """
    Solve the 0/1 Knapsack problem using dynamic programming.
    This function computes the maximum total value of items that can be included
    in a knapsack without exceeding the given capacity. Each item can be included
    at most once.

    Args:
        weights (list of int): A list of item weights.
        values (list of int): A list of item values, corresponding to the weights.
        capacity (int): The maximum capacity of the knapsack.

    Returns:
        int: The maximum total value achievable without exceeding the knapsack capacity.

    Example:
        >>> knapsack([1, 2, 3], [10, 20, 30], 6)
        60
    """

    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        w = weights[i - 1]
        v = values[i - 1]

        for cap in range(1, capacity + 1):
            if w <= cap:
                dp[i][cap] = max(v + dp[i - 1][cap - w], dp[i - 1][cap])
            else:
                dp[i][cap] = dp[i - 1][cap]

    return dp[n][capacity]

#displaying the value for knapsack Task 8.2.3
print(knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7))
# Out:
# 9
